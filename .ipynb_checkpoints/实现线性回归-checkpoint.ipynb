# %%
import matplotlib.pyplot as plt
import pandas as pd
import torch

# %%
data = pd.read_csv('./dataset/Income1.csv')

# %%
plt.scatter(data.Education, data.Income)
plt.xlabel('Education')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
# wx + b

# %%
# 分解写法
w = torch.randn(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
w
# Out:
# tensor([-0.5882], requires_grad=True)

# %%
b
# Out:
# tensor([0.], requires_grad=True)

# %%
learning_rate = 0.001

# %%
X = torch.from_numpy(data.Education.values.reshape(-1, 1)).type(torch.FloatTensor)
Y = torch.from_numpy(data.Income.values.reshape(-1, 1)).type(torch.FloatTensor)

# %%
w.shape
# Out:
# torch.Size([1])

# %%
# # 定义训练过程
# for epoch in range(50):
#     for x, y in zip(X, Y):
#         y_pred = torch.matmul(w, x) + b
#         # 损失函数
#         loss = (y - y_pred).pow(2).sum()

#         # pytorch对一个变量多次求导，求导的结果会累加起来
#         # 梯度归零
#         if w.grad is not None:
#             print(w.grad)
#             w.grad.data.zero_()
#         if b.grad is not None:
#             b.grad.data.zero_()

#         # 反向传播，求w b的导数
#         loss.backward()

#         # 更新w b
#         with torch.no_grad():
#             w.data -= w.grad.data * learning_rate
#             b.data -= b.grad.data * learning_rate
#         print(w)

        # 定义训练过程
for epoch in range(5000):
    for x, y in zip(X, Y):
        # y_pred = torch.matmul(w, x) + b
        y_pred = w * x + b
        # 损失函数
        loss = (y - y_pred).pow(2).sum()
        
        # pytorch对一个变量多次求导, 求导的结果会累加起来. 
        if w.grad is not None:
            # 重置w的导数
            w.grad.data.zero_()
        if b.grad is not None:
            b.grad.data.zero_()
            
        # 反向传播, 即求w,b的导数
        loss.backward()
        
        # 更新w,b
        with torch.no_grad():
            w.data -= w.grad.data * learning_rate
            b.data -= b.grad.data * learning_rate

# %%
w
# Out:
# tensor([5.1277], requires_grad=True)

# %%
plt.scatter(data.Education, data.Income)
plt.xlabel('Education')
plt.ylabel('Income')
plt.plot(X.numpy(), (torch.matmul(X, w) + b).data.numpy(), c='r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 4
#       2 plt.xlabel('Education')
#       3 plt.ylabel('Income')
# ----> 4 plt.plot(X.numpy(), (torch.marmul(X, w) + b).data.numpy(), c='r')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\__init__.py:2216, in __getattr__(name)
#    2213     import importlib
#    2214     return importlib.import_module(f".{name}", __name__)
# -> 2216 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute 'marmul'
